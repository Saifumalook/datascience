# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# loading data
nuqta= sns.load_dataset("dots")
nuqta.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# loading data
nuqta= sns.load_dataset("dots")
# define color palette
p= sns.color_palette("rocket_r")
sns.relplot(data=nuqta, x="time", y="firing_rate",
           hue="coherence", size="choice", col="align",
           kind="line",size_order=["T1", "T2"],palette=p,
           height=5, aspect=.75, facet_kws=dict(sharex=False),)

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# loading data
diamonds= sns.load_dataset("diamonds")
diamonds.head()
f,ax=plt.subplots(figsize=(6.5,6.5))
sns.despine(f,left=True, bottom=True)
clarity_ranking=["I1","SI2","SI1","VS2","VS1","VVS2","VVS1","IF"]
sns.scatterplot(x="carat", y="price",hue="clarity", size="depth",
                palette="ch:r=-.2,d=.3_r",hue_order=clarity_ranking,
                sizes=(1,8),linewidth=0,data=diamonds,ax=ax)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# loading data
nuqta= sns.load_dataset("dots")
nuqta.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
f,ax=plt.subplots(figsize=(6.5,6.5))
sns.boxenplot(x="choice", y="coherence",color="b",
              scale="linear",data=nuqta)
# Out:
# <AxesSubplot:xlabel='choice', ylabel='coherence'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# Load the example flights dataset and convert to long-form
flights_long = sns.load_dataset("flights")
flights_long
# flights = flights_long.pivot("month", "year", "passengers")

# # Draw a heatmap with the numeric values in each cell
# f, ax = plt.subplots(figsize=(9, 6))
# sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set_theme()
# Load data
abs=pd.read_excel("heatmap.xlsx")
abs.head()
# Out:
#           Genes genotypes         FC
# 0        LOX1/2   B73-Con   1.158093
# 1  LOX3 (9-LOX)   B73-Con   0.107393
# 2  LOX4 (9-LOX)   B73-Con   3.510998
# 3  LOX5 (9-LOX)   B73-Con   2.834378
# 4  LOX6 (9-LOX)   B73-Con  47.119521

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set_theme()
# Load data
abs=pd.read_excel("heatmap.xlsx")
abs.head()
# Out:
#           Genes genotypes         FC
# 0        LOX1/2   B73-Con   1.158093
# 1  LOX3 (9-LOX)   B73-Con   0.107393
# 2  LOX4 (9-LOX)   B73-Con   3.510998
# 3  LOX5 (9-LOX)   B73-Con   2.834378
# 4  LOX6 (9-LOX)   B73-Con  47.119521

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# Load the example flights dataset and convert to long-form
abs = abs.pivot("Genes","genotypes","FC")

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(abs, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/1v/9t46rvpn3ws0j0jzsy3kzhn40000gn/T/ipykernel_61793/1188717590.py in <module>
#       8 # Draw a heatmap with the numeric values in each cell
#       9 f, ax = plt.subplots(figsize=(9, 6))
# ---> 10 sns.heatmap(abs, annot=True, fmt="d", linewidths=.5, ax=ax)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     551     if square:
# ...

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Load the example tips dataset
tips = sns.load_dataset("tips")
tips.head()

# # Draw a nested violinplot and split the violins for easier comparison
# sns.violinplot(data=tips, x="day", y="total_bill", hue="smoker",
#                split=True, inner="quart", linewidth=1,
#                palette={"Yes": "b", "No": ".85"})
# sns.despine(left=True)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Load the example tips dataset
abs=pd.read_excel("heatmap.xlsx")
abs.head()

# Draw a nested violinplot and split the violins for easier comparison
sns.violinplot(data=tips, x="day", y="total_bill", hue="smoker",
               split=True, inner="quart", linewidth=1,
               palette={"Yes": "b", "No": ".85"})
sns.despine(left=True)
# Out:
#           Genes genotypes         FC
# 0        LOX1/2   B73-Con   1.158093
# 1  LOX3 (9-LOX)   B73-Con   0.107393
# 2  LOX4 (9-LOX)   B73-Con   3.510998
# 3  LOX5 (9-LOX)   B73-Con   2.834378
# 4  LOX6 (9-LOX)   B73-Con  47.119521

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# loading data
sf=pd.read_excel("fgfr.xlsx")
sf.head()
# sns.boxplot(x="genotypes", y="mass",data=sf)
# Out:
#    groups  mass
# 0  B73_SF    39
# 1  B73_SF    34
# 2  B73_SF    42
# 3  B73_SF    34
# 4  B73_SF    27

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# loading data
sf=pd.read_excel("fgfr.xlsx")
sf.head()
sns.boxplot(x="groups", y="mass",data=sf)
# Out:
# <AxesSubplot:xlabel='groups', ylabel='mass'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# loading data
sf=pd.read_excel("fgfr.xlsx")
sf.head()
sns.boxplot(x="groups", y="mass",data=sf, palette="Set2",
           dodge=True)
# Out:
# <AxesSubplot:xlabel='groups', ylabel='mass'>
