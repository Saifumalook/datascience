# %% [markdown]
# # **Chapter 8.**

# %% [markdown]
# # Pandas notebook tutorial (Day 11)

# %% [markdown]
# This tutorial explains xxx, xxx , xxx

# %% [markdown]
# # How to install libraries.

# %% [markdown]
# #pip install pandas
#
# #pip install numpy

# %% [markdown]
# # Import libraries

# %% [markdown]
# #import pandas as pd
# #import numpy as np

# %%
import pandas as pd
import numpy as np

# %%
# Object creation
s=pd.Series([1,2,3,4,5,6,7,8,9,87,7,7,6,5,43,3,2])
s

# %%
#How to creat empty cell in Series?
s1=pd.Series([1,2,3,np.nan,5,2,7])
s1

# %%
#How to creat Series of date?
s2=pd.date_range("20220707", periods=7)
s2

# %%
dates=pd.date_range("20220707", periods=20)
df=pd.DataFrame(np.random.randn(20,4),index=dates, columns=list("ABCD"))
df

# %%
#How to create same kind (as above) of dataset by dictionaries?
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["girl", "women", "test", "train"]),
        "F": "female",
    }
)


df2

# %%
df2.dtypes

# %%
#How to view dataset?
df.head(5)

# %%
#How to view dataset tail?
df.tail(5)

# %%
#How to index of dataset? Index means row headings
df.index

# %%
#How to index of dataset? Index means row headings
df2.index

# %%
#How to convert dataframe into numpy?
df.to_numpy()

# %%
#How to check quick statistics of data?
df.describe()

# %%
#How to transpose data?
df.T

# %%
#Sorting by ascending or descending order.
df.sort_index(axis=1, ascending=False)

# %%
#Sorting by ascending or descending order.
df.sort_index(axis=1, ascending=True)

# %%
#Sorting by Values or column
df.sort_values(by="B", ascending= True)

# %%
# Selecting a single column.

df["A"]

# %%
df["B"]

# %%
#Selection of data by row wise:
df[0:2]
# Out:
#                    A         B         C         D
# 2022-07-07 -1.704633 -0.158214 -0.055683 -0.514507
# 2022-07-08  0.386612  0.200570  1.449984  0.301750

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2022-07-07 -1.704633 -0.158214 -0.055683 -0.514507
# 2022-07-08  0.386612  0.200570  1.449984  0.301750
# 2022-07-09  2.137770  0.397851  0.160753  1.304055

# %%
df[0:4]
# Out:
#                    A         B         C         D
# 2022-07-07 -1.704633 -0.158214 -0.055683 -0.514507
# 2022-07-08  0.386612  0.200570  1.449984  0.301750
# 2022-07-09  2.137770  0.397851  0.160753  1.304055
# 2022-07-10 -1.114591  1.395949  1.014473 -0.206770

# %%
df[0:10]
# Out:
#                    A         B         C         D
# 2022-07-07 -1.704633 -0.158214 -0.055683 -0.514507
# 2022-07-08  0.386612  0.200570  1.449984  0.301750
# 2022-07-09  2.137770  0.397851  0.160753  1.304055
# 2022-07-10 -1.114591  1.395949  1.014473 -0.206770
# 2022-07-11  0.457318  1.126077 -1.387801  0.619877
# 2022-07-12  1.207212  1.457119  0.354956 -1.562524
# 2022-07-13 -0.114695 -0.312303  1.305247 -0.190790
# 2022-07-14  0.910667  1.300091  1.005717 -1.566945
# 2022-07-15  0.675473  0.504101  2.949969 -0.589228
# 2022-07-16 -0.310785  1.162149 -0.256968 -1.538468

# %%
df[1:3]
# Out:
#                    A         B         C         D
# 2022-07-08  0.386612  0.200570  1.449984  0.301750
# 2022-07-09  2.137770  0.397851  0.160753  1.304055

# %%
#Selection by label¶e.g., we can get data of specif date.
df.loc[dates[0]]
# Out:
# A   -1.704633
# B   -0.158214
# C   -0.055683
# D   -0.514507
# Name: 2022-07-07 00:00:00, dtype: float64

# %%
df.loc[dates[15]]
# Out:
# A    0.132906
# B    0.285758
# C    1.339146
# D   -0.656824
# Name: 2022-07-22 00:00:00, dtype: float64

# %%
#Selecting on a multi-axis by label:
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2022-07-07 -1.704633 -0.158214
# 2022-07-08  0.386612  0.200570
# 2022-07-09  2.137770  0.397851
# 2022-07-10 -1.114591  1.395949
# 2022-07-11  0.457318  1.126077
# 2022-07-12  1.207212  1.457119
# 2022-07-13 -0.114695 -0.312303
# 2022-07-14  0.910667  1.300091
# 2022-07-15  0.675473  0.504101
# 2022-07-16 -0.310785  1.162149
# 2022-07-17  0.773905 -0.130535
# 2022-07-18 -0.825457 -1.746006
# 2022-07-19 -0.840293  0.063689
# 2022-07-20  0.261290  1.680596
# 2022-07-21  0.665780 -1.539801
# 2022-07-22  0.132906  0.285758
# 2022-07-23  0.353193 -2.348718
# 2022-07-24  0.328703  0.335372
# 2022-07-25 -1.933977  0.346613
# 2022-07-26 -0.045767 -0.357068

# %%
# selcting by date wise or rowwise and column wise.
df.loc["20220707":"20220708", ["A", "B"]]
# Out:
#                    A         B
# 2022-07-07 -1.704633 -0.158214
# 2022-07-08  0.386612  0.200570

# %%
df.loc["20220710", ["A", "B","C"]]
# Out:
# A   -1.114591
# B    1.395949
# C    1.014473
# Name: 2022-07-10 00:00:00, dtype: float64

# %%
#For getting a scalar value:
df.loc[dates[2], "A"]
# Out:
# 2.137769751405559

# %%
df.at[dates[15], "A"]
# Out:
# 0.13290573557959542

# %%
df.iloc[3]
# Out:
# A   -1.114591
# B    1.395949
# C    1.014473
# D   -0.206770
# Name: 2022-07-10 00:00:00, dtype: float64

# %%
#data selecting by position
df.iloc[3:10]
# Out:
#                    A         B         C         D
# 2022-07-10 -1.114591  1.395949  1.014473 -0.206770
# 2022-07-11  0.457318  1.126077 -1.387801  0.619877
# 2022-07-12  1.207212  1.457119  0.354956 -1.562
# 2022-07-14  0.910667  1.300091  1.005717 -1.566945
# 2022-07-15  0.675473  0.504101  2.949969 -0.589228
# 2022-07-16 -0.310785  1.162149 -0.256968 -1.538468
# 2022-07-17  0.773905 -0.130535 -0.157154 -0.811496
# 2022-07-18 -0.825457 -1.746006  0.238145  0.725764
# 2022-07-19 -0.840293  0.063689  1.026311 -1.327154
# 2022-07-20  0.261290  1.680596  0.079919 -2.530152
# 2022-07-21  0.665780 -1.539801 -0.282640  0.236821
# 2022-07-22  0.132906  0.285758  1.339146 -0.656824
# 2022-07-23  0.353193 -2.348718 -0.596535  0.792637
# ...

# %%
df2["E"] = ["one", "one", "two", "three", "four", "three","one",
            "one", "two", "three", "four", "three","one", "one", "two",
            "three", "four", "three","four", "three"]
df2
# Out:
#                    A         B         C         D      E
# 2022-07-07 -1.704633 -0.158214 -0.055683 -0.514507    one
# 2022-07-08  0.386612  0.200570  1.449984  0.301750    one
# 2022-07-09  2.137770  0.397851  0.160753  1.304055    two
# 2022-07-10 -1.114591  1.395949  1.014473 -0.206770  three
# 2022-07-11  0.457318  1.126077 -1.387801  0.619877   four
# 2022-07-12  1.207212  1.457119  0.354956 -1.562524  three
# 2022-07-13 -0.114695 -0.312303  1.305247 -0.190790    one
# 2022-07-14  0.910667  1.300091  1.005717 -1.566945    one
# 2022-07-15  0.675473  0.504101  2.949969 -0.589228    two
# 2022-07-16 -0.310785  1.162149 -0.256968 -1.538468  three
# 2022-07-17  0.773905 -0.130535 -0.157154 -0.811496   four
# 2022-07-18 -0.825457 -1.746006  0.238145  0.725764  three
# 2022-07-19 -0.840293  0.063689  1.026311 -1.327154    one
# 2022-07-20  0.261290  1.680596  0.079919 -2.530152    one
# 2022-07-21  0.665780 -1.539801 -0.282640  0.236821    two
# ...

# %%
df2["new"]=[1.4,2.2,2.1,1.2,3.2,1.4,2.2,2.1,1.2,3.2,
               1.4,2.2,2.1,1.2,3.2,1.4,2.2,2.1,1.2,3.2]
df2
# Out:
#                    A         B         C         D      E  mean  new
# 2022-07-07 -1.704633 -0.158214 -0.055683 -0.514507    one   1.4  1.4
# 2022-07-08  0.386612  0.200570  1.449984  0.301750    one   2.2  2.2
# 2022-07-09  2.137770  0.397851  0.160753  1.304055    two   2.1  2.1
# 2022-07-10 -1.114591  1.395949  1.014473 -0.206770  three   1.2  1.2
# 2022-07-11  0.457318  1.126077 -1.387801  0.619877   four   3.2  3.2
# 2022-07-12  1.207212  1.457119  0.354956 -1.562524  three   1.4  1.4
# 2022-07-13 -0.114695 -0.312303  1.305247 -0.190790    one   2.2  2.2
# 2022-07-14  0.910667  1.300091  1.005717 -1.566945    one   2.1  2.1
# 2022-07-15  0.675473  0.504101  2.949969 -0.589228    two   1.2  1.2
# 2022-07-16 -0.310785  1.162149 -0.256968 -1.538468  three   3.2  3.2
# 2022-07-17  0.773905 -0.130535 -0.157154 -0.811496   four   1.4  1.4
# 2022-07-18 -0.825457 -1.746006  0.238145  0.725764  three   2.2  2.2
# 2022-07-19 -0.840293  0.063689  1.026311 -1.327154    one   2.1  2.1
# ...

# %%
df2=df2.iloc[:,0:4]
df2
# Out:
#                    A         B         C         D
# 2022-07-07 -1.704633 -0.158214 -0.055683 -0.514507
# 2022-07-08  0.386612  0.200570  1.449984  0.301750
# 2022-07-09  2.137770  0.397851  0.160753  1.304055
# 2022-07-10 -1.114591  1.395949  1.014473 -0.206770
# 2022-07-11  0.457318  1.126077 -1.387801  0.619877
# 2022-07-12  1.207212  1.457119  0.354956 -1.562524
# 2022-07-13 -0.114695 -0.312303  1.305247 -0.190790
# 2022-07-14  0.910667  1.300091  1.005717 -1.566945
# 2022-07-15  0.675473  0.504101  2.949969 -0.589228
# 2022-07-16 -0.310785  1.162149 -0.256968 -1.538468
# 2022-07-17  0.773905 -0.130535 -0.157154 -0.811496
# 2022-07-18 -0.825457 -1.746006  0.238145  0.725764
# 2022-07-19 -0.840293  0.063689  1.026311 -1.327154
# 2022-07-20  0.261290  1.680596  0.079919 -2.530152
# 2022-07-21  0.665780 -1.539801 -0.282640  0.236821
# 2022-07-22  0.132906  0.285758  1.339146 -0.656824
# 2022-07-23  0.353193 -2.348718 -0.596535  0.792637
# ...
