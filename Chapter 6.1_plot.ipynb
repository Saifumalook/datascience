# %% [markdown]
# # **Chapter 6.**
# ### Graph plotting of different datasets

# %%
# body mass index (BMI)
# Input Weight
# Height 
# BMI (Ask your height to yourself)
#Weight
# calculate BMI
#print BMI (my name .... and my BMI is ....)

# %%
height = input("what is your height? ")
# Out:
# what is your height? 1.70

# %%
height= float(height)

# %%
weight= input("what is your weight? ")
# Out:
# what is your weight? 72

# %%
weight=float(weight)

# %%
BMI = weight/height**2
BMI
# Out:
# 24.913494809688583

# %%
name= input("my name is?  ")
# Out:
# my name is?  Saif

# %%
print("my name is", name, "and my BMI is", BMI,)
# Out:
# my name is Saif and my BMI is 24.913494809688583

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
sns.set_theme(style="ticks", color_codes=True)
titanic = sns.load_dataset("titanic")
sns.catplot(x="sex", y="survived", hue="class", kind="bar",data=titanic)
plt.show()

# %%
sns.set_theme(style="ticks", color_codes=True)
titanic = sns.load_dataset("titanic")
p1 = sns.countplot(x="sex",hue="class",data=titanic)
p1. set_title("plot for counting")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
sns.set_theme(style="ticks", color_codes=True)
titanic= sns.load_dataset("titanic")
g=sns.FacetGrid(titanic, row="sex", hue= "alone")
g=(g.map(plt.scatter, "age", "fare").add_legend())
plt.show()
